# %%
import torch
import pandas as pd
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from torch.optim import Optimizer
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from useful_functions import *
from optimizer import *
from model import *
from MNIST_data_process import *
import matplotlib.pyplot as plt
from tqdm import tqdm
from training import *
from mlxtend.data import mnist_data
from accuracy_compute import *
from data_preparation import *
# Out:
# /home/rocky/environments/train_pytorch/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
n=5
one=np.ones(n)
I=np.eye(n)
R=np.outer(one,one)/n
A,B=R,I
h_data,y_data,X_test,y_test=prepare_node_5()

# %%
l,a=train_PullSum(n=n,A=A,B=B,model_class=MNISTClassifier_4layer,seed_for_model=49,criterion_class=nn.CrossEntropyLoss,epochs=1000,lr=(3e-4/n),X_train_data=h_data,y_train_data=y_data,X_test_data=X_test,y_test_data=y_test,compute_accuracy=compute_accuracy_multiclass)
# Out:
# Training Progress: 100%|██████████| 1000/1000 [02:33<00:00,  6.50it/s, accuracy=82.3400000000%, epoch=1000, loss=0.5140415132]

# %%
n=5
A=get_xinmeng_like_matrix(n,seed=120228).T
B=get_B(A=A,u=2*n,n=n)
h_data,y_data,X_test,y_test=prepare_node_5()

# %%
show_row(A)
# Out:
# A的第二大特征值: 0.5408060786860147
# A的beta: 0.7926004696904292
# A的spectral gap: 0.2073995303095708
# A的kappa: 5.228479210709661
# S_A是: 57.23054190658645

# %%
l1,a1=train_PullSum(n=n,A=A,B=B,model_class=MNISTClassifier_2layer,seed_for_model=49,criterion_class=nn.CrossEntropyLoss,epochs=1500,lr=(1e-4/n),X_train_data=h_data,y_train_data=y_data,X_test_data=X_test,y_test_data=y_test,compute_accuracy=compute_accuracy_multiclass)
# Out:
# ...
# Training Progress: 100%|██████████| 1500/1500 [01:38<00:00, 15.27it/s, accuracy=89.9000000000%, epoch=1500, loss=0.1444796801]

# %%
L1,A1=train_PullDiag(n=n,A=A,model_class=MNISTClassifier_2layer,seed_for_model=49,criterion_class=nn.CrossEntropyLoss,epochs=1000,lr=(2e-4/n),X_train_data=h_data,y_train_data=y_data,X_test_data=X_test,y_test_data=y_test,compute_accuracy=compute_accuracy_multiclass)
# Out:
# Training Progress: 100%|██████████| 1000/1000 [01:06<00:00, 15.12it/s, accuracy=39.7600000000%, epoch=1000, loss=1.4759089947]
