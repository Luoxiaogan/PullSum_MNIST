# %%
import torch
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from torch.optim import Optimizer
import torch.nn as nn
import torch.nn.functional as F
from useful_functions import *
from optimizer import *
from model import *
from MNIST_data_process import *
import matplotlib.pyplot as plt
from tqdm import tqdm
from training import *

# %%
n=5
d=784
I=np.eye(n)
A=get_xinmeng_matrix(n=n).T 
A=0.8*A+0.2*I
B=get_B(A=A,u=2*n,n=n)
epochs=300

# %% [markdown]
# <font color=red>并没有像学长提供的图片那样，那么的显著，我觉得是矩阵去的不好</font>

# %% [markdown]
# 最优参数
#
# PullSum: lr=0.21

# %%
l1,a1=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.5/n))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:29<00:00, 10.05it/s, accuracy=97.6845151954%, epoch=300, loss=0.0632233389]

# %%
l2,a2=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.4/n))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:30<00:00,  9.84it/s, accuracy=97.5397973951%, epoch=300, loss=0.0677940845]

# %%
l3,a3=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.3/n))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:31<00:00,  9.46it/s, accuracy=97.5397973951%, epoch=300, loss=0.0737757608]

# %%
l4,a4=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.22/n))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:30<00:00,  9.92it/s, accuracy=97.4674384949%, epoch=300, loss=0.0864873722]

# %%
l5,a5=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.21/n))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:29<00:00, 10.18it/s, accuracy=97.4240231548%, epoch=300, loss=0.0898847193]

# %%
l6,a6=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.23/n))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:31<00:00,  9.45it/s, accuracy=97.4674384949%, epoch=300, loss=0.0842160270]

# %%
plt.plot(l1, color='r',linestyle='-',label='Sum, lr=0.5')
plt.plot(l2, color='b',linestyle='-',label='Sum, lr=0.4')
plt.plot(l3, color='g',linestyle='-',label='Sum, lr=0.3')
plt.plot(l4, color='orange',linestyle='-',label='Sum, lr=0.22')
plt.plot(l5, color='black',linestyle='-',label='Sum, lr=0.21')
plt.title('Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend() 
plt.show()

# %%
plt.plot(a1, color='r',linestyle='-',label='Sum, lr=0.5')
plt.plot(a2, color='b',linestyle='-',label='Sum, lr=0.4')
plt.plot(a3, color='g',linestyle='-',label='Sum, lr=0.3')
plt.plot(a4, color='orange',linestyle='-',label='Sum, lr=0.22')
plt.plot(a5, color='black',linestyle='-',label='Sum, lr=0.21')
plt.title('Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend() 
plt.show()

# %% [markdown]
# PullDiag: 最优参数

# %%
L1,A1=train_PullDiag(n=n,d=d,A=A,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=0.1)
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:29<00:00, 10.08it/s, accuracy=97.5397973951%, epoch=300, loss=0.0644342296]

# %%
plt.plot(l1, color='r',linestyle='-',label='Sum, lr=0.5')
plt.plot(L1, color='b',linestyle='-',label='Diag, lr=0.1')
plt.title('Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend() 
plt.show()

plt.plot(a1, color='r',linestyle='-',label='Sum, lr=0.5')
plt.plot(A1, color='b',linestyle='-',label='Diag, lr=0.1')
plt.title('Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend() 
plt.show()

# %%
L2,A2=train_PullDiag(n=n,d=d,A=A,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.22/5))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:29<00:00, 10.11it/s, accuracy=97.3950795948%, epoch=300, loss=0.0864688188]

# %%
plt.plot(l4, color='r',linestyle='-',label='Sum, lr=0.22')
plt.plot(L2, color='b',linestyle='-',label='Diag, lr=0.22/n')
plt.title('Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend() 
plt.show()

plt.plot(a4, color='r',linestyle='-',label='Sum, lr=0.22')
plt.plot(A2, color='b',linestyle='-',label='Diag, lr=0.22/n')
plt.title('Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend() 
plt.show()

# %%
L3,A3=train_PullDiag(n=n,d=d,A=A,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.21/5))
# Out:
# Training Progress: 100%|███████████████████████████████████████████| 300/300 [00:29<00:00, 10.08it/s, accuracy=97.3950795948%, epoch=300, loss=0.0903375611]

# %% [markdown]
# 当学习率都小到PullSum（取lr）和PullDiag（取$\frac{\text{lr}}{n}$）都不再震荡之后，两者相差无几

# %%
plt.plot(l5, color='r',linestyle='-',label='Sum, lr=0.21')
plt.plot(L3, color='b',linestyle='-',label='Diag, lr=0.21/n')
plt.title('Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend() 
plt.show()

plt.plot(a5, color='r',linestyle='-',label='Sum, lr=0.21')
plt.plot(A3, color='b',linestyle='-',label='Diag, lr=0.21/n')
plt.title('Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend() 
plt.show()

# %%
plt.plot(a5, color='r',linestyle='-',label='Sum, lr=0.21')
plt.plot(a4, color='g',linestyle='--',label='Sum, lr=0.22')
plt.plot(a6, color='b',linestyle='--',label='Sum, lr=0.23')
#plt.plot(A3, color='b',linestyle='-',label='Diag, lr=0.21/n')
plt.title('Accuracy History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend() 
plt.show()

# %% [markdown]
# 1. PullSum可以耐受更大的学习率

# %%
n=6
d=784
I=np.eye(n)
A=get_xinmeng_matrix(n=n).T 
A=0.8*A+0.2*I
B=get_B(A=A,u=2*n,n=n)
epochs=600

# %%
l,a=train_PullSum(n=n,d=d,A=A,B=B,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=(0.122/n))
# Out:
# Training Progress: 100%|██████████| 600/600 [01:15<00:00,  7.93it/s, accuracy=97.4674384949%, epoch=600, loss=0.0804118949]

# %%
L1,A1=train_PullDiag(n=n,d=d,A=A,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=0.025)
# Out:
# Training Progress: 100%|██████████| 600/600 [01:12<00:00,  8.27it/s, accuracy=97.5397973951%, epoch=600, loss=0.0726816716]

# %%
L2,A2=train_PullDiag(n=n,d=d,A=A,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=2e-2)
# Out:
# Training Progress: 100%|██████████| 600/600 [01:13<00:00,  8.17it/s, accuracy=97.4674384949%, epoch=600, loss=0.0814518022]

# %%
L3,A3=train_PullDiag(n=n,d=d,A=A,seed_for_model=49,criterion=nn.BCELoss(),epochs=epochs,lr=4e-2)
# Out:
# Training Progress: 100%|██████████| 600/600 [01:14<00:00,  8.09it/s, accuracy=97.5397973951%, epoch=600, loss=0.0640664753]

# %%
#plt.plot(L3, color='g',linestyle='-',label='Diag, lr=0.04')
plt.plot(l, color='b',linestyle='-',label='Sum, lr=0.122')
plt.plot(L1, color='g',linestyle='--',label='Diag, lr=0.025')
plt.plot(L2, color='r',linestyle='-',label='Diag, lr=0.02')
plt.title('Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend() 
plt.show()
